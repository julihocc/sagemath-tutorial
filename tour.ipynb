# %% [markdown]
# # Welcome to Sage
#
# Let's begin by using Sage as a calculator. You can add, subtract, multiply, and divide numbers just like you would with a calculator. For further information, you can check the [official tour](https://doc.sagemath.org/html/en/a_tour_of_sage/index.html). First, Sagemath could be used as a powerful scientific calculator, but in a more programmatic way.

# %%
3+5
# Out:
# 8

# %%
57.1^100
# Out:
# 4.60904368661396e175

# %%
x = 2
y = sin(pi*x)
print(y)
# Out:
# 0

# %% [markdown]
# Indeed, Sage is a superset of Python! It means that you can use all the Python syntax and libraries in Sage. In this notebook, we will cover the basics of Sage and Python.

# %%
def hello(name):
    return "Hello, " + name + "!"

print(hello("world"))
# Out:
# Hello, world!

# %%
for i in range(5):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
if 3 > 2:
    print("3 is greater than 2")
# Out:
# 3 is greater than 2

# %% [markdown]
# It's straightforward to use Sage to perfom linear algebra operations. For example, you can create matrices and vectors, and perform operations like addition, subtraction, multiplication, and inversion. ALthough, this could accomplished with the `numpy`, `scipy`, `sympy` and related library in Python, Sage provides a more user-friendly interface, with a more complete set of functionalities.

# %%
A = matrix([[1,2],[3,4]])
B = A^(-1) 
A*B
# Out:
# [1 0]
# [0 1]

# %% [markdown]
# Also, you can use Sage as as CAS (Computer Algebra System) to solve equations, simplify expressions, and plot functions.

# %%
a = var('a')
integral = integrate(sqrt(a)*sqrt(1+a), a)
print(integral)
# Out:
# 1/4*((a + 1)^(3/2)/a^(3/2) + sqrt(a + 1)/sqrt(a))/((a + 1)^2/a^2 - 2*(a + 1)/a + 1) - 1/8*log(sqrt(a + 1)/sqrt(a) + 1) + 1/8*log(sqrt(a + 1)/sqrt(a) - 1)

# %%
x = var('x')
S = solve(x^2 - 2*x - 8 == 0, x)    
S[0].rhs(), S[1].rhs()
# Out:
# (-2, 4)

# %%
show(plot(sin(x) + sin(1.6*x), 0, 40))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Sage is a very powerful calculator. To experience it, first we create a $500\times500$ matrix of random numbers, compute its eigenvalues, and then plot them.

# %%
m = random_matrix(RDF, 500)
m
# Out:
# 500 x 500 dense matrix over Real Double Field (use the '.str()' method to see the entries)

# %%
e = m.eigenvalues()  
w = [(i, abs(e[i])) for i in range(len(e))]
show(points(w))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Sage can handle very large numbers, even numbers with millions or billions of digits.

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
n = factorial(1000000)  
len(n.digits())
# Out:
# 5565709

# %%
N(pi, digits=100)
# Out:
# 3.141592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117068

# %% [markdown]
# Although there are other software that can do the same things as Sage, Sage is free and open-source, and it is very easy to use. Moreover, Sage has advanced capabilities that are not available in other software.

# %%
R.<x,y> = QQ[]
F = factor(x^9 + y^9)
F
# Out:
# (x + y) * (x^2 - x*y + y^2) * (x^6 - x^3*y^3 + y^6)

# %%
F.expand()
# Out:
# x^99 + y^99

# %% [markdown]
# Sage takes less than 1 second to compute the numbers of ways to partition one hundred million as a sum of positive integers.

# %%
z = Partitions(10^8).cardinality()  
z
# Out:
# ...

# %% [markdown]
# ### Why Sage?
#
# - Sage is the world’s most advanced open source math software.
# - Sage is a free and open-source software that is very easy to use.
# - Sage is a superset of Python, which means that you can use all the Python syntax and libraries in Sage.
# - Sage can handle very large numbers, even numbers with millions or billions of digits.
# - Sage has advanced capabilities that are not available in other software.
#
#
# **Without any further ado, let's start with the basics of Sage and Python!**
